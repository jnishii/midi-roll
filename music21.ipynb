# %% [markdown]
# # music21 grpah examples
# https://web.mit.edu/music21/doc/usersGuide/usersGuide_22_graphing.html

# %%
from music21 import *

# %%
path="data/pedb2_v0.0.1.b/"
targetxml="bac-wtc101-p-a-p1/bac-wtc101-p.xml"
targetmid="bac-wtc101-p-a-p1/bac-wtc101-p-a-p1.mid"

piecemid=converter.parse(path+targetmid)
piecexml=converter.parse(path+targetxml)
piece=piecemid

# %%
piecexml.measures(13,16).show()
#piece.measures(14,18).show()

# %%
piecexml.show('midi')
# Out:
#                 <div id="midiPlayerDiv1033718"></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer("#midiPlayerDiv1033718");
#                                mp.base64Load("data:audio/midi;base64,...");
#                         });
#                 </script>

# %%
piece.plot()
# piece.plot('horizontalbar')
# Out:
# <music21.graph.plot.HorizontalBarPitchSpaceOffset for <music21.stream.Score 0x1205b7160>>

# %%
piece.plot('scatter', 'quarterLength', 'pitch', title=target)
# Out:
# <music21.graph.plot.ScatterPitchSpaceQuarterLength for <music21.stream.Score 0x1205b7160>>

# %%
piece.plot('scatter', 'pitchClass', 'quarterLength')
# Out:
# <music21.graph.plot.ScatterPitchClassQuarterLength for <music21.stream.Score 0x1205b7160>>

# %%
#piece.plot('scatter', 'dynamics')

# %%
piece.plot('histogram', 'octave', xHideUnused=False, yAxisLabel='Number of Pitches')
#piece.plot('histogram', 'pitch')
# Out:
# <music21.graph.plot.Histogram for <music21.stream.Score 0x1205b7160>>

# %%
piece.plot('histogram', 'pitchClass')
# Out:
# <music21.graph.plot.HistogramPitchClass for <music21.stream.Score 0x1205b7160>>

# %%
piece.plot('colorgrid')
# Out:
# <music21.graph.plot.WindowedKey for <music21.stream.Score 0x1205b7160>>

# %%
piece.plot('horizontalbarweighted')
# Out:
# <music21.graph.plot.HorizontalBarWeighted for <music21.stream.Score 0x1205b7160>>

# %%
piece.plot('3dbars')
# Out:
# <music21.graph.plot.Plot3DBarsPitchSpaceQuarterLength for <music21.stream.Score 0x1205b7160>>
